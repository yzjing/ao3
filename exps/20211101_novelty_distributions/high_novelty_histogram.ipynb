# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import random
from scipy import stats, spatial
import pickle
import csv
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.axes_grid1.colorbar import colorbar
# Out:
# /opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning:
# The mpl_toolkits.axes_grid1.colorbar module was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use matplotlib.colorbar instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
tfidf_path = '../../data/tfidf_merged_chs_20210915/'

# %%
# lda_path = '../../data/lda_merged_chs_202001_full/'

# %%
fandom_list = [item for item in os.listdir(tfidf_path) if 'tsv' in item]

# %%
fandom_list = [item.split('_temporal')[0] for item in fandom_list]

# %%
fandom_list
# Out:
# ['sherlock_holmes_&_related_fandoms',
#  'the_walking_dead_&_related_fandoms',
#  'doctor_who_&_related_fandoms',
#  'shakespare_william_works',
#  'arthurian_mythology_&_related_fandoms',
#  'haikyuu',
#  'dragon_age_all_media_types',
#  'dcu',
#  'ms_paint_adventures',
#  'one_direction',
#  'hamilton_miranda',
#  'tolkien_j_r_r_works_&_related_fandoms',
#  'buffy_the_vampire_slayer',
#  'attack_on_titan',
#  'bishoujo_senshi_sailor_moon',
#  'star_wars_all_media_types',
#  'harry_potter',
#  'les_miserables_all_media_types',
#  'marvel',
#  'hetalia_axis_powers',
#  'kuroko_no_basuke',
#  'supernatural',
#  'naruto']

# %%
# fandom_list

# %%
def normalize_dfs(df):
    
    # normalization of the success field
    df = df.replace([np.inf, -np.inf], np.nan)
    df['Hits'].fillna(0, inplace=True)
    df['Kudos'].fillna(0, inplace=True)
    df['Bookmarks'].fillna(0, inplace=True)
    df['Comments'].fillna(0, inplace=True)

    # normalize by chapter number
    df['Kudos'] = df['Kudos']/df['Chapters'] 
    df = df.replace([np.inf, -np.inf], np.nan)
    df['Kudos'].dropna()

    df['Hits'] = df['Hits']/df['Chapters']
    df = df.replace([np.inf, -np.inf], np.nan)
    df['Hits'].dropna()

    df['Bookmarks'] = df['Bookmarks']/df['Chapters']
    df = df.replace([np.inf, -np.inf], np.nan)
    df['Bookmarks'].dropna()
    return df

# %%
def check_term_dist(fandom_name):
#     df_topic = pd.read_csv(os.path.join(lda_path, fandom_name + \
#                                         '_temporal_lda_jsd_toprev_with_dist_merged_chs_no_text.tsv'), sep='\t')
#     df_topic = normalize_dfs(df_topic)
#     # highest 10%
#     topic_high_th = np.percentile(df_topic.JSD,90)
#     # lowest 10%
#     topic_low_th = np.percentile(df_topic.JSD, 10)
#     topic_high = df_topic[df_topic.JSD > topic_high_th ]
#     topic_mod = df_topic[(df_topic.JSD <= topic_high_th) & (df_topic.JSD > topic_low_th) ]
#     topic_low = df_topic[df_topic.JSD < topic_low_th ]

#     plt.figure()
#     plt.hist(topic_high.Kudos, density=True, alpha=0.5, label='high novelty')
# #     plt.yscale('log')
#     plt.title(fandom_name + ' ' + 'Topic')
#     plt.hist(topic_mod.Kudos, density=True, alpha=0.5, label='mid novelty')
# #     plt.yscale('log')
#     plt.hist(topic_low.Kudos, density=True, alpha=0.5, label='low novelty')
#     plt.yscale('log')
#     plt.legend()
    
    df_term = pd.read_csv(os.path.join(tfidf_path, fandom_name + \
                                       '_temporal_tfidf_cos_merged_chapters_no_sample_20210915.tsv'), sep='\t')
    df_term = normalize_dfs(df_term)
#     print(fandom_name)
#     print(np.percentile(df_term.Cos, 90))
#     print(np.percentile(df_term.Cos, 10))
    # highest 10%
    plt.figure()
    plt.hist(df_term.Cos, bins=10)
    plt.title(fandom_name)
    plt.figure()
    plt.hexbin(df_term.Cos, np.log(df_term.Kudos), gridsize=20)

    
    term_high_th = np.percentile(df_term.Cos, 90)
    # lowest 10%
    term_low_th = np.percentile(df_term.Cos, 10)
    term_med_th1 = np.percentile(df_term.Cos, 45)
    term_med_th2 = np.percentile(df_term.Cos, 55)

    term_high = df_term[df_term.Cos > term_high_th ]
    term_med = df_term[(df_term.Cos <= term_med_th2) & (df_term.Cos > term_med_th1) ]
    term_low = df_term[df_term.Cos < term_low_th ]

    max_kudos = max(max(term_high.Kudos), max(term_med.Kudos), max(term_low.Kudos))
    bins = np.linspace(0, max_kudos, 10)
    
    plt.figure()
    plt.hist(term_high.Kudos, density=True, alpha=0.4, bins=bins, label='high novelty')
    plt.yscale('log')
    plt.title(fandom_name + ' term')
    plt.hist(term_med.Kudos, density=True, alpha=0.4, bins=bins,label='mid novelty' )
    plt.yscale('log')
    plt.hist(term_low.Kudos, density=True, alpha=0.4, bins=bins,label='low novelty')
    plt.yscale('log')
    plt.legend()

# %%
for fandom in fandom_list:
    check_term_dist(fandom)
# Out:
# /opt/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:50: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:33: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
marvel = pd.read_csv(tfidf_path+'marvel_temporal_tfidf_cos_merged_chapters_full.tsv', sep='\t')

# %%
marvel.head(2)
# Out:
#    index AdditionalTags            ArchiveWarnings           Author  \
# 0   1142             AU  No Archive Warnings Apply  inlovewithnight
# 1   1832    AU, What-If  No Archive Warnings Apply      Lys ap Adin
#
#    Bookmarks Category  Chapters                       Characters  \
# 0          4      F/M         1  Scott Summers, Jean Grey, Logan
# 1          8      M/M         1                Wolverine, Gambit
#
#                   Fandoms    Hits  ...             Relationship  \
# 0  ['X-Men (Movieverse)']   263.0  ...  Scott Summers/Jean Grey
# 1  ['X-Men (Movieverse)']  1329.0  ...         Wolverine/Gambit
#
#                            Title   Words PublishDate UpdateDate  CompleteDate  \
# 0            Eyes Burning Bright  2838.0  2009-11-21        NaN    2009-11-21
# 1  These Fragments, Against Ruin  2148.0  2009-11-14        NaN    2009-11-14
#
#   Comments                                                URL       Cos  \
# 0        0  http://archiveofourown.org/works/18238?view_ad...  0.344911
# 1        2  http://archiveofourown.org/works/9198?view_adu...  0.441596
#
#     Entropy
# 0  5.514196
# 1  5.457043
#
# [2 rows x 23 columns]

# %%
marvel[marvel.Title.str.contains('Mistake')].Title.tolist()
# Out:
# ['Traveled This Far on the Back of Every Mistake',
#  'Mistaken Identity',
#  'The Best Mistake to Make',
#  'Everything (The Last Mistake)',
#  'Rookie Mistake',
#  'My Game, Your Mistake',
#  'All That Love, All Those Mistakes',
#  'Mistakes',
#  'The Mistake',
#  'Trolling the Press: Mistakes Have Been Made',
#  'Fighting Not to Make Mistakes',
#  'An Honest Mistake',
#  'Mistake',
#  'Repeating Past Mistakes',
#  'A Big Mistake',
#  'Mistakes',
#  'My Only Mistake',
#  "Mistakes (or I\\'m Blue, Da Ba De)",
#  'Maladjusted Geniuses and Mistaken Heroes',
#  'Innocent Mistakes',
#  'Fate Made A Mistake',
#  "These Facts We\\'ve Mistaken for Our Lives",
#  'The French Mistake',
#  'Babysitting Mistake',
#  'One Mistake is Not a Crime',
#  'Fun with Mistaken Identities?',
#  'Mistakes are made, but Prices need to be paid',
#  'When Ashes Fall And Are Mistaken For Snow',
#  'Mistaken Identity',
#  'The Worst Mistakes',
#  'A Beautiful Mistake',
#  'A Case of Mistaken Identities',
#  'Mistakes',
#  'Mistakes we made',
#  'Just One Mistake',
#  'Mistaken Identity',
#  'Favorite Mistake',
#  'Mistake',
#  'Best Mistake I Never Made',
#  'The Mistaken',
#  "Five Times TJ Hammond was Mistaken for Bucky Barnes (and One Time He Wasn\\'t)",
#  'Five Times a Mistaken Crush',
#  'For All of Our Mistakes',
#  'Mistakes Of Our Fathers',
#  'Easily Mistaken',
#  'Mistakes That You Do Mean',
#  'You Look Like My Next Mistake',
#  'Mistakes Forgiven',
#  'Murder By Mistake',
#  'Final Call For Last Mistakes',
#  'Mistaken Identity',
#  'Mistakes Made in Happiness',
#  'Keep Repeating Mistakes for Souvenirs',
#  'Mistaken Meanings',
#  'M is for Mistakes',
#  'The Mistake',
#  'The Case of Mistaken Identity',
#  'Mistaken For Strangers',
#  'No Way You Could Mistake Him For Your Man',
#  'Mistaken Identity',
#  "Mistakes (Don\\'t) Happen",
#  'My One Mistake',
#  'Drunken Mistakes, Hangovers, and Bets!',
#  'Drunken Mistakes, Hangovers, and Bets!',
#  'The Mistake She Never Made',
#  'Thunderstruck ~Mistaken Identity~',
#  'I Needed Saving, and a Good Mistake Needed Making. (Maybe You Need the Same Thing)',
#  '"This Was A Mistake"',
#  'Mistakes Heavier Than Gravity',
#  'Memories&amp;Mistakes',
#  'A Stumble Into Svartalfheim Was Only Your First Mistake',
#  "Matt Murdock\\'s Massive Mistake",
#  "A Father\\'s Mistake",
#  'Mistaken']

# %%
df = pd.read_csv('../../data/fanfic_regression_data_merged_chs.tsv', sep='\t')

# %%
df.head(2)
# Out:
#    Bookmarks  Chapters    Hits  Kudos    Words  Comments  \
# 0         21        24  2399.0   53.0  66258.0        16
# 1          7         1  2333.0   80.0   3542.0         3
#
#                                                  URL  Term_novelty   Entropy  \
# 0  http://archiveofourown.org/works/488677/chapte...      0.603058  5.315078
# 1  http://archiveofourown.org/works/208853?view_a...      0.452716  5.723015
#
#                                                 Dist  ...  Fandom_tolkien  \
# 0  [0.000955473, 0.008187229, 0.0005799397, 0.001...  ...               0
# 1  [3.522977e-05, 1.2239097e-05, 0.16778131, 0.00...  ...               0
#
#    Fandom_shakespare  Fandom_hetalia  Fandom_attack_on_titan  \
# 0                  0               0                       0
# 1                  0               0                       0
#
#    Fandom_ms_paint_adventures  Fandom_marvel  Fandom_sailor_moon  \
# 0                           0              0                   0
# 1                           0              0                   0
#
#    Fandom_one_direction  Fandom_sherlock  History
# 0                     0                0   4280.0
# 1                     0                0   4285.0
#
# [2 rows x 55 columns]

# %%
marvel_original = pd.read_csv('../../data/marvel_preprocessed.tsv', sep='\t')

# %%
del marvel_original['Text']

# %%
marvel_original.to_csv('marvel_preprocessed_notext.tsv', sep='\t')

# %%
marvel_original.head(2)
# Out:
#                                       AdditionalTags  \
# 0  Polyamory, Threesome - M/M/M, Magical Healing ...
# 1  it\'s there if you squint okay, Originally Pos...
#
#              ArchiveWarnings            Author  Bookmarks  Category  \
# 0  No Archive Warnings Apply       SailorChibi          2  M/MMulti
# 1  No Archive Warnings Apply  littleskywatcher          0       F/F
#
#    ChapterIndex  Chapters                                         Characters  \
# 0           NaN         1  Tony Stark, Pepper Potts, Steve Rogers, James ...
# 1           NaN         1                     Nita Callahan, Natasha Romanov
#
#    Comments CompleteDate  ...  \
# 0         0   2016-05-14  ...
# 1         2   2016-02-16  ...
#
#                                                Notes  PublishDate     Rating  \
# 0  I found this on my USB stick. I... don\'t even...   2016-05-14     Mature
# 1                          \n            Inspired by   2016-02-16  Not Rated
#
#                                    Relationship  \
# 0  James "Bucky" Barnes/Steve Rogers/Tony Stark
# 1                 Nita Callahan/Natasha Romanov
#
#                                              Summary  \
# 0  "What, that fucking you might give you a bit o...
# 1  After Fury\'s death, Nita gets an unexpected n...
#
#                                                 Text  \
# 0  \nThe words don\'t really register until Peppe...
# 1  \nNita\xe2\x80\x99s couch squeaks as someone p...
#
#                                                Title  \
# 0  the (unexpected) side effects of really awesom...
# 1                           And the Moon Is No Dream
#
#                                                  URL UpdateDate   Words
# 0  http://archiveofourown.org/works/6845182?view_...        NaN  2277.0
# 1  http://archiveofourown.org/works/6028957?view_...        NaN  1095.0
#
# [2 rows x 24 columns]

# %%
marvel_original[marvel_original.Title.str.contains('Groot')]
# Out:
#                                            AdditionalTags  \
# 141611                                                NaN
# 162686                                       Child Reader
# 177751  Flora Colossus, Groot Must Grow, Reflection, P...
# 203076               Drabble, 3 parts, very introspective
# 214908  cumflation, Vomit, Sickness, Tentacles, Tentac...
# 215276  Team Bonding, Humor, Team Dynamics, Team Fluff...
# 219999  I had to do it, There are only 2 other fics of...
# 222003                                                NaN
# 228891                                                NaN
# 236364                           One-Shot, Brotps, Comedy
# 236381                           One-Shot, Brotps, Comedy
# 236397                           One-Shot, Brotps, Comedy
# 238320                                      Team Dynamics
# 240668                                         I Am Groot
# 272907                                               NSFW
# 276569                                                NaN
#
#                                   ArchiveWarnings             Author  \
# 141611                  No Archive Warnings Apply             misura
# 162686                  No Archive Warnings Apply      KOREAlchemist
# 177751                  No Archive Warnings Apply       Cordelia_Sun
# 203076  Creator Chose Not To Use Archive Warnings             CMS521
# 214908                               Rape/Non-Con      DontBeAZombie
# 215276  Creator Chose Not To Use Archive Warnings          RavenGrey
# 219999                  No Archive Warnings Apply  BenvolioPontmercy
# 222003  Creator Chose Not To Use Archive Warnings      andrewshaffer
# 228891                  No Archive Warnings Apply          craziesun
# 236364                  No Archive Warnings Apply     Chelsea_Horror
# 236381                  No Archive Warnings Apply     Chelsea_Horror
# 236397                  No Archive Warnings Apply     Chelsea_Horror
# 238320                  No Archive Warnings Apply      JenTheSweetie
# 240668                  No Archive Warnings Apply            isabeau
# 272907  Creator Chose Not To Use Archive Warnings      sherlocksmyth
# 276569  Creator Chose Not To Use Archive Warnings      KOREAlchemist
#
#         Bookmarks    Category  ChapterIndex  Chapters  \
# 141611          7         Gen           NaN         1
# 162686          4       Other           NaN         1
# 177751          2         Gen           NaN         1
# 203076          3    M/MOther           NaN         1
# 214908          5         M/M           NaN         1
# 215276        147       Other           NaN         1
# 219999         31       Other           NaN         1
# 222003          0         Gen           NaN         1
# 228891         16       Other           NaN         1
# 236364          3         NaN           1.0         3
# 236381          3         NaN           2.0         3
# 236397          3         NaN           3.0         3
# 238320        195         Gen           NaN         1
# 240668          8         Gen           NaN         1
# 272907        212         NaN           NaN         1
# 276569          3  MultiOther           NaN         1
#
#                                                Characters  Comments  \
# 141611  Groot (Marvel), Rocket Raccoon, Peter Quill, D...         2
# 162686                      Groot, Rocket Raccoon, Reader         1
# 177751                                     Rocket Raccoon         8
# 203076  Drax the Destroyer, Groot (Marvel), Peter Quil...         2
# 214908  Rocket Raccoon, Groot (Marvel), Peter Quill, S...         3
# 215276  Peter Quill, Groot (Marvel), Drax the Destroye...        36
# 219999                     Rocket Raccoon, Groot (Marvel)        18
# 222003                                                NaN         0
# 228891              Groot (Marvel), Rocket Raccoon, Groot         4
# 236364  Gamora (Marvel), Groot (Marvel), Peter Quill, ...         0
# 236381  Gamora (Marvel), Groot (Marvel), Peter Quill, ...         0
# 236397  Gamora (Marvel), Groot (Marvel), Peter Quill, ...         4
# 238320  Peter Quill, Rocket Raccoon, Groot (Marvel), G...        40
# 240668                                     Groot (Marvel)         3
# 272907                                     Groot (Marvel)        25
# 276569       Groot, Rocket Raccoon, Reader, Child! Reader         0
#
#        CompleteDate  ...                                              Notes  \
# 141611   2015-06-29  ...                                       For isabeau.
# 162686   2015-01-05  ...                                                NaN
# 177751   2015-01-04  ...                                                NaN
# 203076   2014-12-15  ...  Also posted on Fanfiction.net under same usern...
# 214908   2014-12-04  ...  Just trying to predict whats happening in the ...
# 215276   2014-08-12  ...  Guess who saw Guardians of the Galaxy and love...
# 219999   2014-08-02  ...                                                NaN
# 222003   2014-12-23  ...                                                NaN
# 228891   2014-08-01  ...                                                NaN
# 236364          NaN  ...  First real attempt at GOTG fanfiction,so yeah....
# 236381          NaN  ...                                                NaN
# 236397          NaN  ...                                                NaN
# 238320   2014-08-18  ...  \n          Translation into \xe4\xb8\xad\xe6\...
# 240668   2015-01-01  ...                     \n            A translation of
# 272907   2014-08-04  ...  Had to take a break halfway through writing th...
# 276569   2014-10-07  ...                                                NaN
#
#         PublishDate                 Rating  \
# 141611   2015-06-29      General Audiences
# 162686   2015-01-05      General Audiences
# 177751   2015-01-04      General Audiences
# 203076   2014-12-15  Teen And Up Audiences
# 214908   2014-12-04               Explicit
# 215276   2014-08-12      General Audiences
# 219999   2014-08-02      General Audiences
# 222003   2014-12-23      General Audiences
# 228891   2014-08-01      General Audiences
# 236364   2014-08-19      General Audiences
# 236381   2014-08-19      General Audiences
# 236397   2014-08-19      General Audiences
# 238320   2014-08-18  Teen And Up Audiences
# 240668   2015-01-01      General Audiences
# 272907   2014-08-04               Explicit
# 276569   2014-10-07      General Audiences
#
#                                           Relationship  \
# 141611                                             NaN
# 162686                   Groot/ Reader, Groot x Reader
# 177751                                             NaN
# 203076                        Drax the Destroyer/Groot
# 214908                            Groot/Rocket Raccoon
# 215276                                             NaN
# 219999                            Groot/Rocket Raccoon
# 222003                                             NaN
# 228891  Groot & Rocket Raccoon, Rocket Raccoon & Groot
# 236364                                             NaN
# 236381                                             NaN
# 236397                                             NaN
# 238320                                             NaN
# 240668                                             NaN
# 272907                                             NaN
# 276569                            Groot/Rocket Raccoon
#
#                                                   Summary  \
# 141611  "So how\'d the two of you meet, anyway?" Quill...
# 162686  Flowers crowns are best when shared with friends!
# 177751  Clutching the fragmented remains of his friend...
# 203076  So a 3 part growth of Drax and Groot\'s relati...
# 214908                 Groot is taken over by a Symbiote.
# 215276  It isn\xe2\x80\x99t the weirdest thing that\xe...
# 219999  Yes hello I just wrote a fic about a tree and ...
# 222003  Star-Lord, Groot, and the rest of the merry Gu...
# 228891  Rocket thinks there may have been a huge fight...
# 236364  Rocket causes yet another fight, surprise surp...
# 236381  Rocket causes yet another fight, surprise surp...
# 236397  Rocket causes yet another fight, surprise surp...
# 238320  \n  <i>If Rocket wanted to babysit a stick in ...
# 240668  Groot\'s perspective on Guardians of the Galax...
# 272907  EXTREMELY NSFW fic told from the perspective o...
# 276569   Children should not be left alone on the Milano!
#
#                                                      Text  \
# 141611  \n"So how\'d the two of you meet, anyway?" Qui...
# 162686  \nFlower Crowns (Groot x Child! Reader)\xc2\xa...
# 177751  \nRocket sat in the bright, sterile room of Xa...
# 203076  \nPart 1Groot understood a lot more than his f...
# 214908  \n"Hey, Groot, hand me the thing with the thin...
# 215276  \n\xc2\xa0\n\xc2\xa0 \xc2\xa0 \xc2\xa0 \xc2\xa...
# 219999  \n\xe2\x80\x9cI am Groot.\xe2\x80\x9dRocket Ra...
# 222003  \n"I...am...Groot."\nPeter Quill\xe2\x80\x94a....
# 228891  \nThe dust had long settled on the Ravager shi...
# 236364  \xe2\x80\x9cDamnit!\xe2\x80\x9dA lot more expl...
# 236381  \xe2\x80\x9cIf you do not move your contraptio...
# 236397  He knew it was going to be awkward. He\xe2\x80...
# 238320  \nPeter thought it was a temporary thing.It ma...
# 240668  \nWhere to begin?  It is hard to say.  I can b...
# 272907  \nI am Groot. I am Groot. I am Groot. I am Gro...
# 276569  \nI am Groot (GotG x Child! Reader Drabble) \x...
#
#                                                     Title  \
# 141611     I am Groot (the Lost Amongst the Idiots remix)
# 162686              Flower Crowns (Groot x Child! Reader)
# 177751                                How to Grow a Groot
# 203076            Groot and Drax\'s Budding Relathionship
# 214908                                 The Symbiote Groot
# 215276  Daisy Chains (or Reasons Why Peter Can\'t Leav...
# 219999                                      You Are Groot
# 222003                                     Merry Grootmas
# 228891          That Time Groot and Rocket Won by Default
# 236364                                   Groot\'s flowers
# 236381                                   Groot\'s flowers
# 236397                                   Groot\'s flowers
# 238320               The Care and Feeding of a Baby Groot
# 240668                        I am Groot (Groot\'s Story)
# 272907                                         I Am Groot
# 276569          I am Groot (GotG x Child! Reader Drabble)
#
#                                                       URL  UpdateDate   Words
# 141611           http://archiveofourown.org/works/4227630         NaN   502.0
# 162686           http://archiveofourown.org/works/3124838         NaN   592.0
# 177751           http://archiveofourown.org/works/3115325         NaN   701.0
# 203076           http://archiveofourown.org/works/2776259         NaN   952.0
# 214908  http://archiveofourown.org/works/2715587?view_...         NaN  1262.0
# 215276           http://archiveofourown.org/works/2122635         NaN  2933.0
# 219999           http://archiveofourown.org/works/2066751         NaN   387.0
# 222003           http://archiveofourown.org/works/2829779         NaN  3269.0
# 228891           http://archiveofourown.org/works/2060592         NaN   831.0
# 236364  http://archiveofourown.org/works/2163717/chapt...  2014-08-19  1875.0
# 236381  http://archiveofourown.org/works/2163717/chapt...  2014-08-19  1875.0
# 236397  http://archiveofourown.org/works/2163717/chapt...  2014-08-19  1875.0
# 238320           http://archiveofourown.org/works/2160489         NaN  1608.0
# 240668           http://archiveofourown.org/works/3072956         NaN   328.0
# 272907  http://archiveofourown.org/works/2080878?view_...         NaN  1308.0
# 276569           http://archiveofourown.org/works/2419079         NaN   285.0
#
# [16 rows x 24 columns]
